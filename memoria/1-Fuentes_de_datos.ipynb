# %% [markdown]
# ## FUENTES DE DATOS UTILIZADAS:
# * Consorcio de transportes de Madrid: [enlace](https://datos.crtm.es/search?q=*)
# * Metro de Madrid: [enlace](https://www.metromadrid.es/es/transparencia/proyectos-y-datos)
